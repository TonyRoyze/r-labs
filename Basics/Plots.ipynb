# %%
par(mfrow = c(3, 1))

# %% [markdown]
# # Scatter Plot

# %%
plot(x, y,
  main = "Title",
  xlab = "X Label",
  ylab = "Y Label",
  type = "l", lwd = "5",
  ylim = c(0, 10)
)

# %% [markdown]
# # Histogram

# %%
hist(data,
  main = "Title",
  xlab = "X Label",
  ylab = "Y Label", 
  col = "skyblue", border = "white",
  prob = TRUE,
  ylim = c()
)

# %% [markdown]
# # Function

# %%
curve(8/x^3, from = 2, to = 1000, n = 101, col = "red", lwd = 2, type = "l", add = TRUE)
